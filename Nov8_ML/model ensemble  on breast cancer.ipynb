# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt
from sklearn.calibration import LabelEncoder

# %%
bcancer = pd.read_csv('BreastCancer.csv', index_col=0)
lbl = LabelEncoder()
bcancer['Class'] = lbl.fit_transform(bcancer['Class'])

X = bcancer.drop('Class', axis=1)
y = bcancer['Class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=23, stratify=y)

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC


svm = SVC(probability=True, random_state=23)
lr = LogisticRegression()
nb = GaussianNB()
voting = VotingClassifier(estimators=[('SVM',svm),('LR',lr),('NB',nb)], voting='soft')
voting.fit(X_train, y_train)
y_pred_prob = voting.predict_proba(X_test)[:,1]
print(log_loss(y_test, y_pred_prob))
y_pred = voting.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.1377657178736647
# 0.9571428571428572

# %% [markdown]
# Grid Search CV

# %%
print(voting.get_params)

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=23)
params = {'SVM__gamma':['scale','auto'],'SVM__C':np.linspace(0.001,5,5), 'LR__penalty':['l1','l2','elastic',None], 'NB__var_smoothing':np.linspace(0.0001,0.999,5)}
gcv = GridSearchCV(voting, param_grid=params, cv=kfold,verbose=3, scoring='neg_log_loss', n_jobs=8)
gcv.fit(X,y)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.2s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.2s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.2s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.2s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.2s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.2s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.2s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.2s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.2s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.49955, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.749275, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=0.001, SVM__gamma=scale;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=5.0, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=0.001, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=3.75025, SVM__gamma=scale;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=0.950 total time=   0.1s
# [CV 4/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=0.943 total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=0.964 total time=   0.1s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=auto;, score=0.971 total time=   0.2s
# [CV 2/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=scale;, score=0.986 total time=   0.2s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=0.943 total time=   0.1s
# [CV 5/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=3.75025, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=0.986 total time=   0.1s
# [CV 3/5] END LR__penalty=l1, NB__var_smoothing=0.999, SVM__C=5.0, SVM__gamma=auto;, score=nan total time=   0.1s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=0.957 total time=   0.1s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=0.971 total time=   0.1s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=0.986 total time=   0.1s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=scale;, score=0.943 total time=   0.2s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=0.979 total time=   0.2s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=0.943 total time=   0.1s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=auto;, score=0.986 total time=   0.2s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=scale;, score=0.950 total time=   0.1s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=scale;, score=0.964 total time=   0.2s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=0.979 total time=   0.2s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=0.950 total time=   0.1s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=0.986 total time=   0.2s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=scale;, score=0.950 total time=   0.1s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=auto;, score=0.957 total time=   0.2s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=scale;, score=0.986 total time=   0.1s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=scale;, score=0.979 total time=   0.3s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=0.986 total time=   0.2s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=auto;, score=0.964 total time=   0.2s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=0.943 total time=   0.2s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=scale;, score=0.957 total time=   0.3s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=scale;, score=0.986 total time=   0.1s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=auto;, score=0.943 total time=   0.2s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=0.964 total time=   0.2s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=auto;, score=0.950 total time=   0.2s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=auto;, score=0.979 total time=   0.2s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=auto;, score=0.957 total time=   0.2s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=0.001, SVM__gamma=auto;, score=0.943 total time=   0.2s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=scale;, score=0.950 total time=   0.1s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=auto;, score=0.979 total time=   0.2s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=scale;, score=0.950 total time=   0.1s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=0.957 total time=   0.2s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=scale;, score=0.950 total time=   0.3s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=auto;, score=0.986 total time=   0.2s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=scale;, score=0.950 total time=   0.3s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=0.986 total time=   0.1s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=auto;, score=0.943 total time=   0.2s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=3.75025, SVM__gamma=auto;, score=0.986 total time=   0.2s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=0.979 total time=   0.1s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=auto;, score=0.979 total time=   0.2s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=0.986 total time=   0.1s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=auto;, score=0.964 total time=   0.2s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=0.950 total time=   0.1s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=0.935 total time=   0.1s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=auto;, score=0.950 total time=   0.2s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=scale;, score=0.979 total time=   0.3s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=0.928 total time=   0.1s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=0.986 total time=   0.2s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.0001, SVM__C=5.0, SVM__gamma=auto;, score=0.957 total time=   0.2s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=auto;, score=0.950 total time=   0.2s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=0.986 total time=   0.1s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=0.950 total time=   0.2s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=0.950 total time=   0.2s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=0.979 total time=   0.1s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=auto;, score=0.979 total time=   0.2s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=0.986 total time=   0.1s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=scale;, score=0.986 total time=   0.3s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=0.950 total time=   0.1s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=scale;, score=0.986 total time=   0.1s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=0.986 total time=   0.2s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=0.935 total time=   0.2s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=scale;, score=0.986 total time=   0.1s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=0.971 total time=   0.2s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=auto;, score=0.971 total time=   0.2s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=scale;, score=0.935 total time=   0.1s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=scale;, score=0.950 total time=   0.1s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=scale;, score=0.935 total time=   0.1s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=auto;, score=0.986 total time=   0.3s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=0.001, SVM__gamma=scale;, score=0.979 total time=   0.3s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=0.935 total time=   0.2s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=0.986 total time=   0.2s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=auto;, score=0.950 total time=   0.2s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=scale;, score=0.950 total time=   0.1s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=auto;, score=0.986 total time=   0.2s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=auto;, score=0.950 total time=   0.2s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=scale;, score=0.986 total time=   0.1s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=auto;, score=0.986 total time=   0.2s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=0.957 total time=   0.1s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=scale;, score=0.986 total time=   0.1s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=auto;, score=0.986 total time=   0.2s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=scale;, score=0.986 total time=   0.3s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=auto;, score=0.979 total time=   0.2s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=0.928 total time=   0.1s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=auto;, score=0.971 total time=   0.2s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=0.971 total time=   0.1s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=auto;, score=0.935 total time=   0.2s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=3.75025, SVM__gamma=auto;, score=0.935 total time=   0.2s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=0.979 total time=   0.2s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=0.957 total time=   0.2s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=auto;, score=0.986 total time=   0.2s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=scale;, score=0.979 total time=   0.3s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.249825, SVM__C=5.0, SVM__gamma=auto;, score=0.986 total time=   0.2s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=scale;, score=0.957 total time=   0.1s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=0.971 total time=   0.2s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=0.928 total time=   0.1s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=scale;, score=0.957 total time=   0.3s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=0.928 total time=   0.2s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=0.971 total time=   0.2s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=auto;, score=0.979 total time=   0.2s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=scale;, score=0.971 total time=   0.1s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=scale;, score=0.935 total time=   0.3s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=0.957 total time=   0.1s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=0.957 total time=   0.2s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=1.2507499999999998, SVM__gamma=auto;, score=0.986 total time=   0.2s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=scale;, score=0.971 total time=   0.1s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=0.986 total time=   0.2s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=scale;, score=0.928 total time=   0.1s
# [CV 2/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=scale;, score=0.979 total time=   0.3s
# [CV 5/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=auto;, score=0.942 total time=   0.2s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 3/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=5.0, SVM__gamma=scale;, score=0.979 total time=   0.1s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=auto;, score=0.979 total time=   0.2s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=0.001, SVM__gamma=auto;, score=0.957 total time=   0.2s
# [CV 1/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=3.75025, SVM__gamma=auto;, score=0.957 total time=   0.2s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=2.5004999999999997, SVM__gamma=auto;, score=0.979 total time=   0.2s
# [CV 4/5] END LR__penalty=l2, NB__var_smoothing=0.49955, SVM__C=5.0, SVM__gamma=scale;, score=0.979 total time=   0.1s
# ...
# 34 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 349, in fit
#     return super().fit(X, transformed_y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 81, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1088, in __call__
#     while self.dispatch_one_batch(iterator):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py", line 36, in _fit_single_estimator
#     estimator.fit(X, y)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'l2', 'elasticnet', 'none' (deprecated), 'l1'} or None. Got 'elastic' instead.
#
# --------------------------------------------------------------------------------
# 36 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 349, in fit
#     return super().fit(X, transformed_y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 81, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1088, in __call__
#     while self.dispatch_one_batch(iterator):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py", line 36, in _fit_single_estimator
#     estimator.fit(X, y)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'none' (deprecated), 'l1', 'elasticnet', 'l2'} or None. Got 'elastic' instead.
#
# --------------------------------------------------------------------------------
# 36 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 349, in fit
#     return super().fit(X, transformed_y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 81, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1088, in __call__
#     while self.dispatch_one_batch(iterator):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py", line 36, in _fit_single_estimator
#     estimator.fit(X, y)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'l2', 'l1', 'elasticnet', 'none' (deprecated)} or None. Got 'elastic' instead.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 349, in fit
#     return super().fit(X, transformed_y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_voting.py", line 81, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1088, in __call__
#     while self.dispatch_one_batch(iterator):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py", line 36, in _fit_single_estimator
#     estimator.fit(X, y)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'none' (deprecated), 'l2', 'elasticnet', 'l1'} or None. Got 'elastic' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.96565262 0.96135663 0.96564234 0.96565262
#  0.96707091 0.96565262 0.96849949 0.96565262 0.96849949 0.96565262
#  0.96849949 0.96849949 0.96561151 0.96562179 0.96705036 0.96562179
#  0.96705036 0.96562179 0.96705036 0.96562179 0.96705036 0.96848921
#  0.96275437 0.96418294 0.96275437 0.96418294 0.96275437 0.96418294
#  0.96275437 0.96418294 0.96705036 0.97134635 0.9613258  0.96418294
#  0.9613258  0.96418294 0.9613258  0.96418294 0.9613258  0.96418294
#  0.96562179 0.96991778 0.95989723 0.96418294 0.95989723 0.96275437
#  0.9613258  0.96418294 0.9613258  0.96418294        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.96565262 0.96135663 0.96564234 0.96565262 0.96707091 0.96565262
#  0.96849949 0.96565262 0.96706064 0.96565262 0.96849949 0.96849949
#  0.96561151 0.96562179 0.96561151 0.96562179 0.96705036 0.96562179
#  0.96705036 0.96562179 0.96705036 0.96848921 0.96275437 0.96418294
#  0.96275437 0.96418294 0.96275437 0.96418294 0.96275437 0.96418294
#  0.96705036 0.97134635 0.9613258  0.96561151 0.9613258  0.96561151
#  0.9613258  0.96561151 0.9613258  0.96561151 0.96562179 0.96991778
#  0.95989723 0.9613258  0.95989723 0.9613258  0.95989723 0.9613258
#  0.9613258  0.9613258 ]
#   warnings.warn(
# {'LR__penalty': 'l2', 'NB__var_smoothing': 0.749275, 'SVM__C': 0.001, 'SVM__gamma': 'auto'}
# 0.9713463514902365
